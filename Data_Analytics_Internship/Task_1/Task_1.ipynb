# %% [markdown]
# # Exploring and Visualizing the Iris Dataset

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Import Dataset

# %%
# Import Dataset from Local System
df = pd.read_csv('iris.csv')

# %% [markdown]
# #### Statistical Analysis Of Data

# %%
df.head()  # To check top rows of Dataset
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape  # To check total rows and columns
# Out:
# (150, 5)

# %%
df.info()    #To check Type of each columns, count of non null values and memory usages
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()  #For Statstical Analysis of Dataset, to check the spread of Data
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.isnull().sum()  #Check overall null values of each column
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.isnull().sum().sum()   # To check total of null vlaues from the entire Dataset
# Out:
# np.int64(0)

# %%
(df.isnull().sum()/df.shape[0]) * 100   # For checking percentage of of null values
# Out:
# sepal_length    0.0
# sepal_width     0.0
# petal_length    0.0
# petal_width     0.0
# species         0.0
# dtype: float64

# %%
df['species'].value_counts()   #For checking Values of each Category
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.dtypes   #For checking the Datatyes of Each Column
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# ###  Data Quality Check
# Till Now We have Inspect our Data Before Analysis, There is no missing values or null Values all the correct with valid Datatypes
# Data is Clean and ready for Analysis.

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
sns.scatterplot(data = df, x='sepal_length', y='sepal_width', hue="species")
plt.title("Sepal Length vs Sepal Width")
plt.subplot(2,2,2)
sns.scatterplot(data = df, x="petal_length", y="petal_width", hue="species")
plt.title("Petal_Length vs Petal_Width")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Scatter Plot Observation
# In these Scatter plot we can say the Relationsip between Sepal_Lenght vs Sepal_Width is Moderate relationship. This is describing that sepal measurements alone may not clearly distinguish flower categories.
#
# In the 2nd chart Petal_Length vs Petal_Width demonstrates a strong and positive relationship where as Petal_Length increase Petal_Width also increase. Distinct clustering among species is visible suggesting that petal measurements are more effective for differentiating iris flower species

# %%
plt.figure(figsize=(13,5))
sns.scatterplot(data = df, x='sepal_length', y='petal_length' , hue='species')
plt.title("Speal_Lenght vs Petal_Lenght Obesrvation ")
plt.show()

# %% [markdown]
# ### Scatter Plot Observation
# The scatter plot indicates a positive relationship between sepal length and petal length. Flowers with larger sepals generally tend to have longer petals, and species grouping is visible across the dataset.

# %%
plt.figure(figsize=(13,5))
sns.boxplot(df)
plt.show()

# %%
plt.figure(figsize=(13,7))   # Set Size of Picture 
plt.subplot(2,2,1)
sns.boxplot(df['sepal_length'])
plt.title("Sepal Length")

plt.subplot(2,2,2)
sns.boxplot(df['sepal_width'])
plt.title("Sepal Width")

plt.subplot(2,2,3)
sns.boxplot(df["petal_length"])
plt.title("Petal Length")

plt.subplot(2,2,4)
sns.boxplot(df["petal_width"])
plt.title("Petal Width")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Box Plot Observation
# BoxPlot Analysis Indicate there are few outlier in the Dataset in Seapl_Width Column. These outlier are very small number of so we don't need to remove then our dataset is clean and useable for Analysis

# %%
plt.figure(figsize=(13,7))
plt.subplot(2,2,1)
sns.histplot(df["sepal_length"], kde=True)
plt.title("Distribution of Sepal Length")

plt.subplot(2,2,2)
sns.histplot(df["sepal_width"], kde=True)
plt.title("Distribution of Sepal Width")

plt.subplot(2,2,3)
sns.histplot(df["petal_length"], kde=True)
plt.title("Distribution of Petal Lenth ")

plt.subplot(2,2,4)
sns.histplot(df["petal_width"], kde=True)
plt.title("Distribution of Petal Width")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Histogram Observation
# The subplot histograms provide a clear comparison of all numerical features in the dataset. It is observed that petal length and petal width have a more distinct distribution pattern, often showing multiple peaks, which indicates strong variation among species. In contrast, sepal length and sepal width are more normally distributed and overlap significantly between species. This suggests that petal features carry more discriminative power for classification than sepal features.
