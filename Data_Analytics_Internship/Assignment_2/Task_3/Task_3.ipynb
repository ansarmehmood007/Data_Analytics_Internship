# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('superstore.csv')

# %%
df.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  Number_of_Record Order.Date        Order.ID  ... Sales  \
# 0       0.0     US                 1    00:00.0  CA-2011-130813  ...    19
# 1       0.0     US                 1    00:00.0  CA-2011-148614  ...    19
# 2       0.0     US                 1    00:00.0  CA-2011-118962  ...    21
# 3       0.0     US                 1    00:00.0  CA-2011-118962  ...   111
# 4       0.0     US                 1    00:00.0  CA-2011-146969  ...     6
#
# ...

# %%
df.shape
# Out:
# (51290, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          51290 non-null  object
#  1   City              51290 non-null  object
#  2   Country           51290 non-null  object
#  3   Customer.ID       51290 non-null  object
#  4   Customer.Name     51290 non-null  object
#  5   Discount          51290 non-null  float64
#  6   Market            51290 non-null  object
#  7   Number_of_Record  51290 non-null  int64
#  8   Order.Date        51290 non-null  object
#  9   Order.ID          51290 non-null  object
#  10  Order.Priority    51290 non-null  object
#  11  Product.ID        51290 non-null  object
#  12  Product.Name      51290 non-null  object
#  13  Profit            51290 non-null  float64
#  14  Quantity          51290 non-null  int64
#  15  Region            51290 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', 'Number_of_Record', 'Order.Date', 'Order.ID',
#        'Order.Priority', 'Product.ID', 'Product.Name', 'Profit', 'Quantity',
#        'Region', 'Row.ID', 'Sales', 'Segment', 'Ship.Date', 'Ship.Mode',
#        'Shipping.Cost', 'State', 'Sub.Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Category            0
# City                0
# Country             0
# Customer.ID         0
# Customer.Name       0
# Discount            0
# Market              0
# Number_of_Record    0
# Order.Date          0
# Order.ID            0
# Order.Priority      0
# Product.ID          0
# Product.Name        0
# Profit              0
# Quantity            0
# Region              0
# Row.ID              0
# Sales               0
# Segment             0
# Ship.Date           0
# Ship.Mode           0
# Shipping.Cost       0
# State               0
# Sub.Category        0
# Year                0
# Market2             0
# weeknum             0
# dtype: int64

# %% [markdown]
# No Missing Values in our Dataset

# %%
df.duplicated().sum()      #Checking Duplicate Values
# Out:
# np.int64(0)

# %% [markdown]
# There is no Duplicat Values

# %%
# Correct Datatype
df['Order.Date'] = pd.to_datetime(df['Order.Date'])
df['Ship.Date'] = pd.to_datetime(df['Ship.Date'])

# %%
df[['Order.Date', 'Ship.Date']].dtypes
# Out:
# Order.Date    datetime64[ns]
# Ship.Date     datetime64[ns]
# dtype: object

# %% [markdown]
# The dataset was inspected for missing values and duplicate records. No missing values or duplicates were found. Date columns (Order.Date and Ship.Date) were converted to datetime format for proper analysis. Numerical columns such as Sales and Profit were already in the correct format.

# %%
df['Sales'].sum()         #Total Sales
# Out:
# np.int64(12642905)

# %%
df['Profit'].sum()        #Total Profit
# Out:
# np.float64(1467457.2912800002)

# %%
top5_customers = (df.groupby('Customer.Name')['Sales'].sum().sort_values(ascending=False).head(5))
top5_customers
# Out:
# Customer.Name
# Tom Ashbrook          40489
# Tamara Chand          37453
# Greg Tran             35552
# Christopher Conant    35187
# Sean Miller           35170
# Name: Sales, dtype: int64

# %% [markdown]
# Top 5 Customer by Sales

# %%
df.groupby('Segment')[['Sales', 'Profit']].sum()     # Total Sales vs Total Profit
# Out:
#                Sales        Profit
# Segment
# Consumer     6508141  749239.78206
# Corporate    3824808  441208.32866
# Home Office  2309956  277009.18056
